# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from slide_analysis_nn.train.datasets_preparation import DatasetPreparation

dataset_preparation = DatasetPreparation()
dataset_preparation.populate_prepared_datasets()
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# processing slide /src/workspace/slide_analysis_nn/slide_analysis_nn/train/datasets/source/slide_images/Tumor_044.tif
# (62829, 140689, 62837, 140692) (62825, 140688, 62841, 140693)
# (36052, 153821, 36057, 153827) (36050, 153818, 36059, 153830)
# (65099, 137514, 65857, 137879) (64720, 137332, 66236, 138061)
# (60275, 149122, 63203, 152682) (58811, 147342, 64667, 154462)
# (64954, 145838, 66131, 146838) (64366, 145338, 66719, 147338)
# (54889, 165912, 59896, 168367) (52386, 164685, 62399, 169594)
# (35765, 153827, 37191, 155129)(58023, 133486, 61232, 136791) (56419, 131834, 62836, 138443)
# (67425, 143628, 69125, 146046) (66575, 142419, 69975, 147255)
# ...

# %%
from slide_analysis_nn.train.train_model import Train

train = Train()
train.start_training()
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# GPU not found
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 96          conv2d_1[0][0]
# ...

# %%
from slide_analysis_nn.prediction.predict import Predict

predict_example = Predict()
prediction = predict_example.predict_slide('/src/workspace/slide_analysis_nn/slide_analysis_nn/train/datasets/source/slide_images/hidden/Tumor_015.tif', area_to_predict=((74000, 74000), (80000, 80000)))
prediction.save_as_asap_annotations(truth_xml_path='/src/workspace/slide_analysis_nn/slide_analysis_nn/train/datasets/source/slide_images/hidden/Tumor_015true.xml')
# print(prediction)
# Out:
# /src/workspace/slide_analysis_nn/slide_analysis_nn/train/snapshots/train_42/slide_analysis_20_2.74.h5
# predict
# 0:13
# [1524564870.9610193, 1524564870.9610193, 1524564870.9610193, 1524564870.9610193, 0.0024394989013671875]
# est = 183512 days, 10:30:58.000942
# 1:13
# [1524564870.9610193, 1524564870.9610193, 1524564870.9610193, 0.0024394989013671875, 0.00036907196044921875]
# est = 127047 days, 1:44:30.926079
# 2:13
# [1524564870.9610193, 1524564870.9610193, 0.0024394989013671875, 0.00036907196044921875, 0.00019979476928710938]
# est = 77639 days, 21:03:52.235104
# 3:13
# [1524564870.9610193, 0.0024394989013671875, 0.00036907196044921875, 0.00019979476928710938, 0.00020241737365722656]
# est = 35290 days, 20:29:01.928460
# 4:13
# [0.0024394989013671875, 0.00036907196044921875, 0.00019979476928710938, 0.00020241737365722656, 0.0001919269561767578]
# est = 0:00:00.006125
# 5:13
# ...
